# %% [markdown]
# # NLP Basics: Learning how to use regular expressions

# %% [markdown]
# ### Using regular expressions in Python
#
# Python's `re` package is the most commonly used regex resource. More details can be found [here](https://docs.python.org/3/library/re.html).

# %%
import re

re_test = 'This is a made up string to test 2 different regex methods'
re_test_messy = 'This      is a made up     string to test 2    different regex methods'
re_test_messy1 = 'This-is-a-made/up.string*to>>>>test----2""""""different~regex-methods'

# %% [markdown]
# ### Splitting a sentence into a list of words

# %%
re.split('\s', re_test) # look for single white space

# %%
re.split('\s+', re_test_messy) # look for one or more white spaces with the \s+

# %%
re.split('\W+', re_test_messy1) # look for  word character

# %%
re.split('\w+', re_test_messy1) # looks for non word charachters
re.findall('\w+', re_test_messy1) # looks for the word and ignores the chracters

# %%
re.findall('\S+', re_test) # look for non white spaces

# %% [markdown]
# ### Replacing a specific string

# %%
pep8_test = 'I try to follow PEP8 guidelines'
pep7_test = 'I try to follow PEP7 guidelines'
peep8_test = 'I try to follow PEEP8 guidelines'

# %%
re.findall('[A-Z]+[0-9]+', pep8_test)
# Out:
# ['PEP8']

# %%
re.sub('[A-Z]+[0-9]+', 'PEP 8 python style guide', pep8_test)
# Out:
# 'I try to follow PEP 8 python style guide guidelines'

# %% [markdown]
# ### Other examples of regex methods
#
# - re.search()
# - re.match()
# - re.fullmatch()
# - re.finditer()
# - re.escape()
